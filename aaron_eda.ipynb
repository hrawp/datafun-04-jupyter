# %% [markdown]
# # EDA Project 4
# ## by Aaron Pelton
# ## 9/17/2024
# ## This project is to determine if we can decide what species an iris flower is based on four categories.
# ## These categories are Petal Length, Petal Width, Sepal Length, and Sepal Width.
# ## I will parse the iris data set finding the 75th, 25th and Percentiles, and Average of each species and plot that information on a bar chart.
# ## This will provide visual cues to the most probable designation we have.
# ## I also will share what category is the best at helping decide the probable species.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Here I load the iris dataset and take a brief look at the data.

# %%
# Load the Iris dataset into DataFrame
df = sns.load_dataset('iris')

# Inspect first rows of the DataFrame
print(df.head(10))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# ## I rename my column headers.

# %%
# Renaming a column
df.rename(columns={'sepal_length': 'Sepal Length'}, inplace=True)
df.rename(columns={'sepal_width': 'Sepal Width'}, inplace=True)
df.rename(columns={'petal_length': 'Petal Length'}, inplace=True)
df.rename(columns={'petal_width': 'Petal Width'}, inplace=True)

# %% [markdown]
# ## I plot the data with pairplot to get an overview of the data and make some decisions on where the data may lead.

# %%
sns.pairplot(df, hue='species')
plt.show()

# %% [markdown]
# ## I include this data to show the sample size.  150 total flowers and 50 of each species.

# %%
# Inspect value counts by categorical column
df['species'].value_counts()

# Inspect value counts for all categorical columns
for col in df.select_dtypes(include=['object', 'category']).columns:
    # Display count plot
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.show()

# Show all plots
plt.show()

# %% [markdown]
# ## The next four cells of code find the Average, 75th, and 25th percentile by species in each category.

# %%
Setosa_75_Perc_Sepal_Length = round(df[df['species'] == 'setosa']['Sepal Length'].quantile(0.75),2)
print(f"Setosa 75 Percentile Sepal Length is: {Setosa_75_Perc_Sepal_Length}")
Versicolor_75_Perc_Sepal_Length = round(df[df['species'] == 'versicolor']['Sepal Length'].quantile(0.75),2)
print(f"Versicolor 75 Percentile Sepal Length is: {Versicolor_75_Perc_Sepal_Length}")
Virginica_75_Perc_Sepal_Length = round(df[df['species'] == 'virginica']['Sepal Length'].quantile(0.75),2)
print(f"Virginica 75 Percentile Sepal Length is: {Virginica_75_Perc_Sepal_Length}")
Setosa_Ave_Sepal_Length = round(df[df['species'] == 'setosa']['Sepal Length'].mean(),2)
print(f"Setosa Average Sepal Length is: {Setosa_Ave_Sepal_Length}")
Versicolor_Ave_Sepal_Length = round(df[df['species'] == 'versicolor']['Sepal Length'].mean(),2)
print(f"Versicolor Average Sepal Length is: {Versicolor_Ave_Sepal_Length}")
Virginica_Ave_Sepal_Length = round(df[df['species'] == 'virginica']['Sepal Length'].mean(),2)
print(f"Virginica Average Sepal Length is: {Virginica_Ave_Sepal_Length}")
Setosa_25_Perc_Sepal_Length = round(df[df['species'] == 'setosa']['Sepal Length'].quantile(0.25),2)
print(f"Setosa 25 Percentile Sepal Length is: {Setosa_25_Perc_Sepal_Length}")
Versicolor_25_Perc_Sepal_Length = round(df[df['species'] == 'versicolor']['Sepal Length'].quantile(0.25),2)
print(f"Versicolor 25 Percentile Sepal Length is: {Versicolor_25_Perc_Sepal_Length}")
Virginica_25_Perc_Sepal_Length = round(df[df['species'] == 'virginica']['Sepal Length'].quantile(0.25),2)
print(f"Virginica 25 Percentile Sepal Length is: {Virginica_25_Perc_Sepal_Length}")
# Out:
# Setosa 75 Percentile Sepal Length is: 5.2
# Versicolor 75 Percentile Sepal Length is: 6.3
# Virginica 75 Percentile Sepal Length is: 6.9
# Setosa Average Sepal Length is: 5.01
# Versicolor Average Sepal Length is: 5.94
# Virginica Average Sepal Length is: 6.59
# Setosa 25 Percentile Sepal Length is: 4.8
# Versicolor 25 Percentile Sepal Length is: 5.6
# Virginica 25 Percentile Sepal Length is: 6.22

# %%
Setosa_75_Perc_Sepal_Width = round(df[df['species'] == 'setosa']['Sepal Width'].quantile(0.75),2)
print(f"Setosa 75 Percentile Sepal Width is: {Setosa_75_Perc_Sepal_Width}")
Versicolor_75_Perc_Sepal_Width = round(df[df['species'] == 'versicolor']['Sepal Width'].quantile(0.75),2)
print(f"Versicolor 75 Percentile Sepal Width is: {Versicolor_75_Perc_Sepal_Width}")
Virginica_75_Perc_Sepal_Width = round(df[df['species'] == 'virginica']['Sepal Width'].quantile(0.75),2)
print(f"Virginica 75 Percentile Sepal Width is: {Virginica_75_Perc_Sepal_Width}")
Setosa_Ave_Sepal_Width = round(df[df['species'] == 'setosa']['Sepal Width'].mean(),2)
print(f"Setosa Average Sepal Width is: {Setosa_Ave_Sepal_Width}")
Versicolor_Ave_Sepal_Width = round(df[df['species'] == 'versicolor']['Sepal Width'].mean(),2)
print(f"Versicolor Average Sepal Width is: {Versicolor_Ave_Sepal_Width}")
Virginica_Ave_Sepal_Width = round(df[df['species'] == 'virginica']['Sepal Width'].mean(),2)
print(f"Virginica Average Sepal Width is: {Virginica_Ave_Sepal_Width}")
Setosa_25_Perc_Sepal_Width = round(df[df['species'] == 'setosa']['Sepal Width'].quantile(0.25),2)
print(f"Setosa 25 Percentile Sepal Width is: {Setosa_25_Perc_Sepal_Width}")
Versicolor_25_Perc_Sepal_Width = round(df[df['species'] == 'versicolor']['Sepal Width'].quantile(0.25),2)
print(f"Versicolor 25 Percentile Sepal Width is: {Versicolor_25_Perc_Sepal_Width}")
Virginica_25_Perc_Sepal_Width = round(df[df['species'] == 'virginica']['Sepal Width'].quantile(0.25),2)
print(f"Virginica 25 Percentile Sepal Width is: {Virginica_25_Perc_Sepal_Width}")
# Out:
# Setosa 75 Percentile Sepal Width is: 3.68
# Versicolor 75 Percentile Sepal Width is: 3.0
# Virginica 75 Percentile Sepal Width is: 3.18
# Setosa Average Sepal Width is: 3.43
# Versicolor Average Sepal Width is: 2.77
# Virginica Average Sepal Width is: 2.97
# Setosa 25 Percentile Sepal Width is: 3.2
# Versicolor 25 Percentile Sepal Width is: 2.52
# Virginica 25 Percentile Sepal Width is: 2.8

# %%
Setosa_75_Perc_Petal_Length= round(df[df['species'] == 'setosa']['Petal Length'].quantile(0.75),2)
print(f"Setosa 75 Percentile Petal Length is: {Setosa_75_Perc_Petal_Length}")
Versicolor_75_Perc_Petal_Length= round(df[df['species'] == 'versicolor']['Petal Length'].quantile(0.75),2)
print(f"Versicolor 75 Percentile Petal Length is: {Versicolor_75_Perc_Petal_Length}")
Virginica_75_Perc_Petal_Length= round(df[df['species'] == 'virginica']['Petal Length'].quantile(0.75),2)
print(f"Virginica 75 Percentile Petal Length is: {Virginica_75_Perc_Petal_Length}")
Setosa_Ave_Petal_Length = round(df[df['species'] == 'setosa']['Petal Length'].mean(),2)
print(f"Setosa Average Petal Length is: {Setosa_Ave_Petal_Length}")
Versicolor_Ave_Petal_Length = round(df[df['species'] == 'versicolor']['Petal Length'].mean(),2)
print(f"Versicolor Average Petal Length is: {Versicolor_Ave_Petal_Length}")
Virginica_Ave_Petal_Length = round(df[df['species'] == 'virginica']['Petal Length'].mean(),2)
print(f"Virginica Average Petal Length is: {Virginica_Ave_Petal_Length}")
Setosa_25_Perc_Petal_Length= round(df[df['species'] == 'setosa']['Petal Length'].quantile(0.25),2)
print(f"Setosa 25 Percentile Petal Length is: {Setosa_25_Perc_Petal_Length}")
Versicolor_25_Perc_Petal_Length= round(df[df['species'] == 'versicolor']['Petal Length'].quantile(0.25),2)
print(f"Versicolor 25 Percentile Petal Length is: {Versicolor_25_Perc_Petal_Length}")
Virginica_25_Perc_Petal_Length= round(df[df['species'] == 'virginica']['Petal Length'].quantile(0.25),2)
print(f"Virginica 25 Percentile Petal Length is: {Virginica_25_Perc_Petal_Length}")
# Out:
# Setosa 75 Percentile Petal Length is: 1.58
# Versicolor 75 Percentile Petal Length is: 4.6
# Virginica 75 Percentile Petal Length is: 5.88
# Setosa Average Petal Length is: 1.46
# Versicolor Average Petal Length is: 4.26
# Virginica Average Petal Length is: 5.55
# Setosa 25 Percentile Petal Length is: 1.4
# Versicolor 25 Percentile Petal Length is: 4.0
# Virginica 25 Percentile Petal Length is: 5.1

# %%
Setosa_75_Perc_Petal_Width= round(df[df['species'] == 'setosa']['Petal Width'].quantile(0.75),2)
print(f"Setosa 75 Percentile Petal Width is: {Setosa_75_Perc_Petal_Width}")
Versicolor_75_Perc_Petal_Width= round(df[df['species'] == 'versicolor']['Petal Width'].quantile(0.75),2)
print(f"Versicolor 75 Percentile Petal Width is: {Versicolor_75_Perc_Petal_Width}")
Virginica_75_Perc_Petal_Width= round(df[df['species'] == 'virginica']['Petal Width'].quantile(0.75),2)
print(f"Virginica 75 Percentile Petal Width is: {Virginica_75_Perc_Petal_Width}")
Setosa_Ave_Petal_Width = round(df[df['species'] == 'setosa']['Petal Width'].mean(),2)
print(f"Setosa Average Petal Width is: {Setosa_Ave_Petal_Width}")
Versicolor_Ave_Petal_Width = round(df[df['species'] == 'versicolor']['Petal Width'].mean(),2)
print(f"Versicolor Average Petal Width is: {Versicolor_Ave_Petal_Width}")
Virginica_Ave_Petal_Width = round(df[df['species'] == 'virginica']['Petal Width'].mean(),2)
print(f"Virginica Average Petal Width is: {Virginica_Ave_Petal_Width}")
Setosa_25_Perc_Petal_Width= round(df[df['species'] == 'setosa']['Petal Width'].quantile(0.25),2)
print(f"Setosa 25 Percentile Petal Width is: {Setosa_25_Perc_Petal_Width}")
Versicolor_25_Perc_Petal_Width= round(df[df['species'] == 'versicolor']['Petal Width'].quantile(0.25),2)
print(f"Versicolor 25 Percentile Petal Width is: {Versicolor_25_Perc_Petal_Width}")
Virginica_25_Perc_Petal_Width= round(df[df['species'] == 'virginica']['Petal Width'].quantile(0.25),2)
print(f"Virginica 25 Percentile Petal Width is: {Virginica_25_Perc_Petal_Width}")
# Out:
# Setosa 75 Percentile Petal Width is: 0.3
# Versicolor 75 Percentile Petal Width is: 1.5
# Virginica 75 Percentile Petal Width is: 2.3
# Setosa Average Petal Width is: 0.25
# Versicolor Average Petal Width is: 1.33
# Virginica Average Petal Width is: 2.03
# Setosa 25 Percentile Petal Width is: 0.2
# Versicolor 25 Percentile Petal Width is: 1.2
# Virginica 25 Percentile Petal Width is: 1.8

# %% [markdown]
# ## Next I show the 75th, Average, and 25th percentile for each category by species in a bar graph.

# %%
# Create a list of data for Petal Width
data = {
    'Species': ['Setosa', 'Setosa', 'Setosa', 'Versicolor', 'Versicolor', 'Versicolor', 'Virginica', 'Virginica', 'Virginica'],
    'Statistic': ['75th Percentile', 'Average', '25th Percentile', '75th Percentile', 'Average', '25th Percentile', '75th Percentile', 'Average', '25th Percentile'],
    'Petal Width': [
        Setosa_75_Perc_Petal_Width,
        Setosa_Ave_Petal_Width,
        Setosa_25_Perc_Petal_Width,
        Versicolor_75_Perc_Petal_Width,
        Versicolor_Ave_Petal_Width,
        Versicolor_25_Perc_Petal_Width,
        Virginica_75_Perc_Petal_Width,
        Virginica_Ave_Petal_Width,
        Virginica_25_Perc_Petal_Width
    ]
}

# Create the DataFrame
Petal_Width_Together = pd.DataFrame(data)

# Print the DataFrame
print(Petal_Width_Together)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Species', y='Petal Width', hue='Statistic', data=Petal_Width_Together)
plt.title('Petal Width Statistics by Species')
plt.ylabel('Petal Width')
plt.xlabel('Species')
plt.legend(title='Statistic')
plt.show()
# Out:
#       Species        Statistic  Petal Width
# 0      Setosa  75th Percentile         0.30
# 1      Setosa          Average         0.25
# 2      Setosa  25th Percentile         0.20
# 3  Versicolor  75th Percentile         1.50
# 4  Versicolor          Average         1.33
# 5  Versicolor  25th Percentile         1.20
# 6   Virginica  75th Percentile         2.30
# 7   Virginica          Average         2.03
# 8   Virginica  25th Percentile         1.80

# %%
# Create a list of data for Petal Length
data = {
    'Species': ['Setosa', 'Setosa', 'Setosa', 'Versicolor', 'Versicolor', 'Versicolor', 'Virginica', 'Virginica', 'Virginica'],
    'Statistic': ['75th Percentile', 'Average', '25th Percentile', '75th Percentile', 'Average', '25th Percentile', '75th Percentile', 'Average', '25th Percentile'],
    'Petal Length': [
        Setosa_75_Perc_Petal_Length,
        Setosa_Ave_Petal_Length,
        Setosa_25_Perc_Petal_Length,
        Versicolor_75_Perc_Petal_Length,
        Versicolor_Ave_Petal_Length,
        Versicolor_25_Perc_Petal_Length,
        Virginica_75_Perc_Petal_Length,
        Virginica_Ave_Petal_Length,
        Virginica_25_Perc_Petal_Length
    ]
}

# Create the DataFrame
Petal_Length_Together = pd.DataFrame(data)

# Print the DataFrame
print(Petal_Length_Together)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Species', y='Petal Length', hue='Statistic', data=Petal_Length_Together)
plt.title('Petal Length Statistics by Species')
plt.ylabel('Petal Length')
plt.xlabel('Species')
plt.legend(title='Statistic')
plt.show()
# Out:
#       Species        Statistic  Petal Length
# 0      Setosa  75th Percentile          1.58
# 1      Setosa          Average          1.46
# 2      Setosa  25th Percentile          1.40
# 3  Versicolor  75th Percentile          4.60
# 4  Versicolor          Average          4.26
# 5  Versicolor  25th Percentile          4.00
# 6   Virginica  75th Percentile          5.88
# 7   Virginica          Average          5.55
# 8   Virginica  25th Percentile          5.10

# %%
# Create a list of data for Sepal Length
data = {
    'Species': ['Setosa', 'Setosa', 'Setosa', 'Versicolor', 'Versicolor', 'Versicolor', 'Virginica', 'Virginica', 'Virginica'],
    'Statistic': ['75th Percentile', 'Average', '25th Percentile', '75th Percentile', 'Average', '25th Percentile', '75th Percentile', 'Average', '25th Percentile'],
    'Sepal Length': [
        Setosa_75_Perc_Sepal_Length,
        Setosa_Ave_Sepal_Length,
        Setosa_25_Perc_Sepal_Length,
        Versicolor_75_Perc_Sepal_Length,
        Versicolor_Ave_Sepal_Length,
        Versicolor_25_Perc_Sepal_Length,
        Virginica_75_Perc_Sepal_Length,
        Virginica_Ave_Sepal_Length,
        Virginica_25_Perc_Sepal_Length
    ]
}

# Create the DataFrame
Sepal_Length_Together = pd.DataFrame(data)

# Print the DataFrame
print(Sepal_Length_Together)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Species', y='Sepal Length', hue='Statistic', data=Sepal_Length_Together)
plt.title('Sepal Length Statistics by Species')
plt.ylabel('Sepal Length')
plt.xlabel('Species')
plt.legend(title='Statistic')
plt.show()
# Out:
#       Species        Statistic  Sepal Length
# 0      Setosa  75th Percentile          5.20
# 1      Setosa          Average          5.01
# 2      Setosa  25th Percentile          4.80
# 3  Versicolor  75th Percentile          6.30
# 4  Versicolor          Average          5.94
# 5  Versicolor  25th Percentile          5.60
# 6   Virginica  75th Percentile          6.90
# 7   Virginica          Average          6.59
# 8   Virginica  25th Percentile          6.22

# %%
# Create a list of data for Sepal Width
data = {
    'Species': ['Setosa', 'Setosa', 'Setosa', 'Versicolor', 'Versicolor', 'Versicolor', 'Virginica', 'Virginica', 'Virginica'],
    'Statistic': ['75th Percentile', 'Average', '25th Percentile', '75th Percentile', 'Average', '25th Percentile', '75th Percentile', 'Average', '25th Percentile'],
    'Sepal Width': [
        Setosa_75_Perc_Sepal_Width,
        Setosa_Ave_Sepal_Width,
        Setosa_25_Perc_Sepal_Width,
        Versicolor_75_Perc_Sepal_Width,
        Versicolor_Ave_Sepal_Width,
        Versicolor_25_Perc_Sepal_Width,
        Virginica_75_Perc_Sepal_Width,
        Virginica_Ave_Sepal_Width,
        Virginica_25_Perc_Sepal_Width
    ]
}

# Create the DataFrame
Sepal_Width_Together = pd.DataFrame(data)

# Print the DataFrame
print(Sepal_Width_Together)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Species', y='Sepal Width', hue='Statistic', data=Sepal_Width_Together)
plt.title('Sepal Width Statistics by Species')
plt.ylabel('Sepal Width')
plt.xlabel('Species')
plt.legend(title='Statistic')
plt.show()
# Out:
#       Species        Statistic  Sepal Width
# 0      Setosa  75th Percentile         3.68
# 1      Setosa          Average         3.43
# 2      Setosa  25th Percentile         3.20
# 3  Versicolor  75th Percentile         3.00
# 4  Versicolor          Average         2.77
# 5  Versicolor  25th Percentile         2.52
# 6   Virginica  75th Percentile         3.18
# 7   Virginica          Average         2.97
# 8   Virginica  25th Percentile         2.80

# %% [markdown]
# ## The data shows that the best category to tell the species is Petal Width, followed by Petal Length, then Sapal Width, and finally Sepal Width.
# ## We have the highest confidence level for finding Setosa by looking at Petal Length and Petal Width.  The size of Setosa are much smaller than the other two species.
# ## We still find a fairly high confidence level to distinguish the species of Versicolor and Virginica apart by Petal Width and Petal Length.
# ## I feel the 25th and 75th percentile give a good picture of what the data is trying to say about determining species based on numbers from these four categories.
